# %%
import pandas as pd

# %%
df_sdk1 = pd.read_csv('/Users/yantingting/Documents/海外风控/巴西/拼接数据&模型初版/df_var_all.csv')

# %%
df_sdk1.columns.tolist()
# Out:
# ['loan_id',
#  'DATE',
#  'flag_result',
#  'is_sample',
#  'var17',
#  'var18',
#  'var9',
#  'var36',
#  'var42',
#  'var43',
#  'age',
#  'society',
#  'var2-C',
#  'var2-O',
#  'var2-S',
#  'var3-0',
#  'var3-5',
#  'var3-6',
#  'var3-7',
#  'var7-MG',
#  'var7-RJ',
#  'var7-SP',
#  'var10-Aposentados e Pensionistas',
#  'var10-Assalariados',
#  'var10-Autonomos',
#  'var10-Empresários',
#  'var10-Funcionários Públicos',
#  'var10-Profissionais Liberais',
#  'var11-F',
#  'var11-M',
#  'var12-',
#  'var12-gmail',
#  'var12-hotmail',
#  'var12-outlook',
#  'var13-0001',
#  'var13-0033',
#  'var13-0104',
#  'var13-0237',
#  'var13-0341',
#  'var21-FALHA',
#  'var21-SEGUE',
#  'var26-CLIENTE NOVO',
#  'var26-JA CLIENTE',
#  'var25-0.0',
#  'var25-1.0',
#  'var22-ABORTA',
#  'var22-APROVA',
#  'var30-NAO_CONSTAM_OCORRENCIAS',
#  'var31-EXISTE_PENDENCIA_FINANCEIRA',
#  'var31-NAO_CONSTAM_OCORRENCIAS',
#  'var32-NAO_CONSTAM_OCORRENCIAS',
#  'var33-NAO_CONSTAM_OCORRENCIAS',
# ...

# %%
list1 = ['var22-ABORTA', 'var22-APROVA','var32-NAO_CONSTAM_OCORRENCIAS', 'var33-NAO_CONSTAM_OCORRENCIAS','var38-ABORTA',
 'var38-APROVA','high_freq_app',
 'mid_freq_app',
 'low_freq_app',
 'cnt_app',
 'rate_high_freq_app',
 'rate_mid_freq_app',
 'rate_low_freq_app','BB','WhatsApp',]
df_sdk1[list1].corr()
# Out:
#                                var22-ABORTA  var22-APROVA  \
# var22-ABORTA                       1.000000     -0.209379
# var22-APROVA                      -0.209379      1.000000
# var32-NAO_CONSTAM_OCORRENCIAS      0.426023      0.788630
# var33-NAO_CONSTAM_OCORRENCIAS      0.437161      0.785404
# var38-ABORTA                      -0.243277     -0.433278
# var38-APROVA                       0.429839      0.785806
# high_freq_app                     -0.053952      0.126387
# mid_freq_app                      -0.022405      0.083925
# low_freq_app                      -0.005183      0.016907
# cnt_app                           -0.039603      0.094946
# rate_high_freq_app                 0.018590     -0.070961
# rate_mid_freq_app                  0.012222     -0.012781
# rate_low_freq_app                 -0.014128      0.025466
# BB                                 0.019729      0.000898
# WhatsApp                           0.034975     -0.100792
#
# ...

# %%
df_sdk1[list1].corr(method = 'kendall')
# Out:
#                                var22-ABORTA  var22-APROVA  \
# var22-ABORTA                       1.000000     -0.209379
# var22-APROVA                      -0.209379      1.000000
# var32-NAO_CONSTAM_OCORRENCIAS      0.426023      0.788630
# var33-NAO_CONSTAM_OCORRENCIAS      0.437161      0.785404
# var38-ABORTA                      -0.243277     -0.433278
# var38-APROVA                       0.429839      0.785806
# high_freq_app                     -0.046431      0.107063
# mid_freq_app                      -0.020665      0.072391
# low_freq_app                      -0.038938      0.058834
# cnt_app                           -0.036327      0.101175
# rate_high_freq_app                 0.015202     -0.056118
# rate_mid_freq_app                  0.008123     -0.009144
# rate_low_freq_app                 -0.036218      0.051940
# BB                                 0.003235      0.028681
# WhatsApp                           0.033875     -0.092853
#
# ...
