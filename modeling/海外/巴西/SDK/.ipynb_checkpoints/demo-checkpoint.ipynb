# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = 'all' #默认为'last'
# %config IPCompleter.greedy=True

# %%
# %matplotlib inline

import os
import sys
import json
import logging
import warnings
warnings.filterwarnings('ignore')
# 更改为自己的路径,或者直接在环境变量中添加
sys.path.append('/Users/yantingting/Documents/genie')

import pandas as pd
import numpy as np
from jinja2 import Template

from imp import reload

from utils3.data_io_utils import *
import utils3.misc_utils as mu
import utils3.summary_statistics as ss
import utils3.metrics as mt
import utils3.feature_selection as fs
import utils3.plotting as pl
import utils3.modeling as ml
from functools import reduce
import xgboost as xgb

# %% [markdown]
# # 须知：
# 如果有有某个函数不明白怎么输入参数，请按shift+Tab并按两次，函数具体用法即会展现

# %% [markdown]
# # 设置数据路径

# %%
# 读取模型相关的变量
Data_path = '/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/01_data'
# 储存模型最终结果
Result_path = '/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/02_result_xgb'

# %% [markdown]
# # 读取数据字典
# B卡中有两部分数据：
# 1、PINTEC衍生数据体系
# 2、NIKE数据体系
#
# 本demo针对NIKE数据体系进行建模，如有有兴趣可以使用PINTEC数据进行建模

# %%
var_dict = pd.read_excel('/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/B_v3_var_dict_PINTEC.xlsx')

# %% [markdown]
# # 引入建模数据

# %%
model_data_origin = load_data_from_pickle(Data_path,'model_data.pkl')

# %%
model_data_origin.shape
# Out:
# (49837, 1355)

# %% [markdown]
# ## 选择有在贷有逾期的人建模（考虑到成本有过逾期的用户最好直接用PINTEC体系数据）
#
# yzd_wyq:有在贷无逾期
#
# yzd_yyq:有在贷有逾期（但是当前没有逾期）
#
# wzd_wqx:无在贷后续无取现
#
# wzd_yqx:无在贷后续有取现

# %%
model_data_origin.tag_final.value_counts()
# Out:
# yzd_wyq    21246
# yzd_yyq    15527
# wzd_wqx    12509
# wzd_yqx      555
# Name: tag_final, dtype: int64

# %%
# yzd_yyq人群比较少，并且逾期率比较低，因此可认为和yzd_wyq人群特性类似
model_data_final = model_data_origin[model_data_origin.tag_final.isin(['yzd_yyq'])]

# %% [markdown]
# ## 为模型数据构建唯一用户标识
# 因为B卡是分层抽样的因此没法用userid作为用户的唯一标识，因为一个人有可能会被好几次命中，因此需要构造一个唯一标识

# %%
model_data_final['applicationid'] = model_data_final.index
# 之后会使用applicationid作为一个用户的唯一标识
model_data_final['applicationid'].head()
# Out:
# 12    12
# 17    17
# 20    20
# 29    29
# 30    30
# Name: applicationid, dtype: int64

# %%
model_data_final['appmon'] = model_data_final['applicationdate'].apply(lambda x : x[:7])

# %% [markdown]
# # 整理X,y数据

# %%
# 此时选出的X数据中就只有字典里边的字段了
X = model_data_final[var_dict[u'指标英文'].unique()]
# 设置用户的唯一标识
X.index = model_data_final.applicationid
# 定义大于30的逾期的用户为坏客户
model_data_final['y'] = np.where(model_data_final.d_y_hismaxdpd>=30,1,0)

# 将y数据单独摘出
y = model_data_final[['y']]
y.index = model_data_final.applicationid

# %% [markdown]
# # 填充缺失值

# %%
X = mu.process_missing(X, var_dict,known_missing={-9999999: -8887})
# Out:
# Warnings: downflag variable is not in downflagmap provided for performance
# Warnings: downflag variable is not in downflagmap provided for payment
# Warnings: downflag variable is not in downflagmap provided for DEVICE
# Warnings: downflag variable is not in downflagmap provided for APPLICATION
# Warnings: downflag variable is not in downflagmap provided for REPAY_DETAIL
# Warnings: downflag variable is not in downflagmap provided for TONGDUN_DETAIL
# Warnings: downflag variable is not in downflagmap provided for model_bScore
# Warnings: downflag variable is not in downflagmap provided for ML

# %% [markdown]
# # 数据类型转换

# %%
# 数据处理过程中出现了分母为0的情况，当时没有发现
X.replace(np.inf,9999,inplace=True)

# %%
X = mu.convert_right_data_type(X, var_dict)[0]

# %% [markdown]
# # EDA
#
# 通过这一步可以得到数据的一些描述性统计数据

# %%
ss.eda(X, var_dict, useless_vars=[], exempt_vars=[],\
       data_path=Result_path, save_label='all')

# %% [markdown]
# # 筛掉Summary excluded变量进行综合排序

# %%
X.shape,y.shape
# Out:
# ((15527, 488), (15527, 1))

# %%
summary = pd.read_excel(os.path.join(Result_path, 'all_variables_summary.xlsx'), encoding='utf-8')
kept = summary.loc[pd.isnull(summary.exclusion_reason), u'指标英文'].tolist()
# 填充缺失值时如果有-8888，X的index会被打乱
X = pd.merge(X,y,left_index=True,right_index=True)[kept]
y = pd.merge(X,y,left_index=True,right_index=True)['y']

# %% [markdown]
# # 划分训练集和测试集

# %%
from sklearn.model_selection import train_test_split
train_apply, test_apply = train_test_split(model_data_final.index, test_size=0.30, random_state=43)

model_data_final.loc[:, 'sample_set'] =\
np.where(model_data_final.index.isin(train_apply), 'train', 'test')

# %%
X_train = X.loc[model_data_final.index.isin(\
list(model_data_final.loc[model_data_final.sample_set=='train'].index))]
X_test = X.loc[model_data_final.index.isin(\
list(model_data_final.loc[model_data_final.sample_set=='test'].index))]
y_train = y.loc[model_data_final.index.isin(\
list(model_data_final.loc[model_data_final.sample_set=='train'].index))]
y_test = y.loc[model_data_final.index.isin(\
list(model_data_final.loc[model_data_final.sample_set=='test'].index))]

# %% [markdown]
# ## 仔细查看train，test数据确保正确

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((10868, 365), (10868,), (4659, 365), (4659,))

# %%
sum(X_train.index != y_train.index),sum(X_test.index != y_test.index)
# Out:
# (0, 0)

# %% [markdown]
# # 各种算法的overall_ranking

# %%
args_dict = {
    'random_forest': {
        'grid_search': False,#选择了True则会进行网格筛选速度会比较慢
        'param': None
    },
    'xgboost': {
        'grid_search': False,
        'param': None
    }
}
methods = [
    'random_forest', 
    'lasso', 
    'xgboost'
]

fs_obj = fs.FeatureSelection()

# %%
# 使用日志在result_path中可以通过日志观察overall_ranking进行到哪一步了
logging.basicConfig(filename=os.path.join(Result_path, 'test_log.log'), level=logging.INFO, filemode='w')
LOG = logging.getLogger(__name__)

# %%
# X_cat_train:变量分箱以后的对应的箱
# X_transformed:变量分箱以后的对应的箱的woe值
# woe_iv_df:变量细分箱结果
# rebin_spec:变量对应的分箱节点
# ranking_result:每个变量通过算法得到的所在排位
# 这一步时间比较长请大家耐心
## 在XGboost中不建议分箱太细，这样极其容易过拟合，num_max_bins建议用5分箱
X_cat_train,X_transformed, woe_iv_df, rebin_spec, ranking_result = fs_obj.overall_ranking(X_train, y_train, \
                                                                            var_dict, args_dict, \
                                                                            methods, num_max_bins=5)
# Out:
# [11:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	train-auc:0.741959	test-auc:0.721603
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [10]	train-auc:0.832097	test-auc:0.804344
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [20]	train-auc:0.852477	test-auc:0.82315
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]	train-auc:0.868506	test-auc:0.833044
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [40]	train-auc:0.881348	test-auc:0.838746
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [50]	train-auc:0.89101	test-auc:0.843293
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [60]	train-auc:0.898692	test-auc:0.84469
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [70]	train-auc:0.905283	test-auc:0.846887
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [80]	train-auc:0.910487	test-auc:0.848438
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# ...
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3

# %% [markdown]
# ## <font size=5 color=red> ***将rebin_spec转换为xgboost使用的格式!*** </font>

# %%
rebin_spec = mu.convert_rebin_spec2XGB_rebin_spec(rebin_spec)

# %% [markdown]
# ## 建议：将X_cat_train、rebin_spec、woe_iv_df这些数据存储出去，这样就算中途挂掉后续也可以不用重来之前的工作，因为overall_ranking还是很消耗时间的

# %%
save_data_to_pickle(X_cat_train,Result_path,'X_cat_train.pkl')
save_data_to_pickle(woe_iv_df,Result_path,'woe_iv_df.pkl')
save_data_to_pickle(rebin_spec,Result_path,'rebin_spec.pkl')
save_data_to_pickle(ranking_result,Result_path,'ranking_result.pkl')
save_data_to_pickle(X_transformed,Result_path,'ranking_result.pkl')

# %% [markdown]
# # 相关性晒变量

# %% [markdown]
# ## 留下整体排名靠前的变量

# %%
# 确定需要留下的排名靠前变量的数量
n = 100
top_n = ranking_result.sort_values('overall_rank')[u'指标英文'].iloc[:n].tolist()

# %%
# 决定从top_n中剔除的字段名称
exclusion = []
# 决定模型一定要有的字段，即使可能不显著
start_from = []
# 通过综合排序选中的
selected = list(set(top_n) - set(exclusion))

# %%
# 将数据分箱后并转换woe值
X_transformed_train = X_transformed
# clean data
X_transformed_train = X_transformed_train[selected]

# %% [markdown]
# ## 相关性筛选

# %%
corr_threshold = 0.7 # 可调
vif_threshold = 10 # 可调
vif_result = fs.Colinearity(X_transformed_train,Result_path)

# %%
# 这一步时间比较长请大家耐心
vif_result.run(ranking_result)

# %%
# 相关性分析删除的变量
exclusion_cols = vif_result.corr_exclude_vars + vif_result.vif_dropvars

# %% [markdown]
# # 调整粗分箱

# %%
selected = list(set(selected) - set(exclusion_cols))
selected
# Out:
# ['OverdueAllNum_his',
#  'riskGrade',
#  'fid2AppDays',
#  'minDrawdownAmtHist',
#  'meanTenorHist',
#  'recent_180D_tongdunBlackDecision',
#  'dueGT3StmtRate30D',
#  'rechargeNum_L30D',
#  'recent_180D_tongdunmicrofinNumPfL6M',
#  'TotalDPD_L3M',
#  'Others_max_apply_interval_his',
#  'lastLogin2Now',
#  'recent_180D_tongdunNormalNumPfL3M',
#  'maxFidDays',
#  'recent_90D_tongdunIdMultiLoanNumPf',
#  'minDQduration_L3M',
#  'minDrawdownHourHist',
#  'fstDrawdown2NowDays',
#  'recent_180D_tongdunotherNumPfL6M',
#  'repayFailNum_his',
#  'maxCuroverdueday',
#  'lstDrawdown2AppDays',
#  'tenor12AmtCLRate180D',
#  'frist3MoB',
#  'meanDrawdownAmtHist',
#  'fstDueLE3ToNowDays',
#  'minDrawdownAmt90D',
#  'rechargeNum_his',
#  'maxDrawdownDPD120D',
#  'apollo_osBalanceSelfProduct',
#  'recent_30D_tongdunotherNumPfL6M',
#  'dueDaysSum30D',
#  'apollo_hisMaxOverdueDays',
#  'lstDrawdown2NowDays']

# %% [markdown]
# ## 图形界面调整分箱(这一步在xgboost中并非必须步骤，但是强烈建议大家看看每个变量是怎么分布的，是否适合拿来拟合模型)

# %%
ui_obj = pl.BinPlotAdjustUI(X_train, y_train, Result_path,Data_path,rebin_spec, var_dict)
ui_obj.main_ui(selected)

# %% [markdown]
# ## 储存调整后的结果

# %%
rebin_spec_bin_adjusted = {k:v for k,v in ui_obj.rebin_spec.items() if k in selected}

# %%
# 针对类别型变量出现的特殊情况，现在不可避免的需要手动修改
rebin_spec_bin_adjusted['riskGrade'] = {1.0: ['RG1', '4', '3', '5', '7','-8887','-8888'],
 2.0: ['RG2'],
 3.0: ['RG3'],
 4.0: ['RG4'],
 5.0: ['RG5', 'RG6']}

# %%
# 依旧建议吧完成的结果存出去，保证后续挂掉以后也能不用重头再来
save_data_to_pickle(rebin_spec_bin_adjusted,Result_path,'rebin_spec_bin_adjusted.pkl')

# %% [markdown]
# ## 训练集按照新的rebin_spec进行分箱

# %%
#apply new bin cutting to the data
bin_obj = mt.BinWoe()
new_X = X_train[selected]
X_cat_train = bin_obj.convert_to_category(new_X, var_dict, rebin_spec_bin_adjusted)
woe_iv_df_coarse = bin_obj.calculate_woe_all(X_cat_train, y_train, var_dict, rebin_spec_bin_adjusted)

# %% [markdown]
# ## 测试集按照新的rebin_spec进行分箱

# %%
new_X = X_test[selected]
X_cat_test = bin_obj.convert_to_category(new_X, var_dict, rebin_spec_bin_adjusted)

# %% [markdown]
# # 按月查看训练集分箱以后的分布以及逾期率

# %% [markdown]
# ## 将分好箱的数据与原数据中的y以及时间标识合并

# %%
X_cat_train_with_y_appmon = pd.merge(X_cat_train,model_data_final[['y','appmon']]\
                                     ,left_index=True,right_index=True)

# %%
# 这一步按月统计了变量的分布以及缺失率，这一步可以将字段先存储出去，观察不合格的变量，在下一步可以提前删除
var_dist_badRate_by_time = ss.get_badRate_and_dist_by_time\
                            (X_cat_train_with_y_appmon,selected,'appmon','y')

# %%
# 建议到这一步的时候讲数据存储出去，观察一下
var_dist_badRate_by_time.to_excel(os.path.join(Result_path,'var_dist_badRate_by_time.xlsx'))

# %%
# 通过观察var_dist_badRate_by_time.xlsx文件决定将按时间分布不稳定的变量删除
exclusion_vars_by_time_dist_and_badrate = ['apollo_hisMaxOverdueDays'\
                                           ,'fid2AppDays']

# %% [markdown]
# # 将变量转化为XGBoost需要的形式

# %% [markdown]
# ## 保存最终留下的字段

# %%
selected_final = list(set(selected) - set(exclusion_vars_by_time_dist_and_badrate))

# %% [markdown]
# ## 保存最终的rebin_spec

# %%
rebin_spec_bin_adjusted_final = {k:v for k,v in rebin_spec_bin_adjusted.items() if k in selected_final}

# %% [markdown]
# ## 将训练集数据进行XGboost转换

# %%
X_train_final = X_train[selected_final]
X_cat_train_final = X_cat_train[selected_final]

# %%
bin_obj = mt.BinWoe()

# %%
# X_train_xgboost:xgboost最终衍生完成的所有变量的集合
# rebin_spec_bin_adjusted_final:最终的分箱文件
# bin_to_label:将分箱转化为标签的dict文件
# dummy_var_name_map:转化为dummy的dict文件
X_train_xgboost, rebin_spec_bin_adjusted_final, bin_to_label, dummy_var_name_map =\
bin_obj.xgboost_data_derive(X_train_final, y_train, var_dict\
                            ,rebin_spec_adjusted=rebin_spec_bin_adjusted_final\
                            , verbose=True)

# %% [markdown]
# ## 将训练集的调整后的分箱数据进行dummy并与之前衍生的数据进行合并（这一步可尝试做，现在看来增益不太大）

# %%
X_train_xgboost_with_bin_dummy = bin_obj.convert_xgboost_rebins_to_dummy(X_train_xgboost,X_cat_train_final,dummy_var_name_map)

# %%
X_train_xgboost_with_bin_dummy.shape
# Out:
# (10868, 225)

# %% [markdown]
# ## 将测试集进行XGboost转转换

# %%
X_test_final = X_test[selected_final]
X_cat_test_final = X_cat_test[selected_final]

# %%
X_test_xgboost = mt.BinWoe().apply_xgboost_data_derive(X_test_final,
                                var_dict, rebin_spec_bin_adjusted_final, bin_to_label)

# %% [markdown]
# ## 将测试集调整后的分箱数据进行dummy并与之前衍生的数据进行合并

# %%
# is_apply = True,将原先train上边的映射逻辑应用
X_test_xgboost_with_bin_dummy = bin_obj.convert_xgboost_rebins_to_dummy(X_test_xgboost,X_cat_test_final\
                                                                        ,dummy_var_name_map,is_apply=True)

# %%
X_test_xgboost_with_bin_dummy.shape
# Out:
# (4659, 223)

# %% [markdown]
# ## 在一些字符型变量中极其容易出现训练集和测试集中从未出现的取值，这时一定要小心，必要时刻可以将特殊取值进行取舍

# %%
set(X_train_xgboost_with_bin_dummy.columns) - set(X_test_xgboost_with_bin_dummy.columns)
# Out:
# {'recent_180D_tongdunBlackDecisionDUMMYAccept',
#  'recent_180D_tongdunBlackDecision_bin_dummy2',
#  'riskGradeDUMMY3',
#  'riskGradeDUMMY7'}

# %%
set(X_test_xgboost_with_bin_dummy.columns) - set(X_train_xgboost_with_bin_dummy.columns)
# Out:
# {'riskGradeDUMMY2', 'riskGrade_-9999'}

# %%
X_train_xgboost_with_bin_dummy.drop(['riskGradeDUMMY3', 'riskGradeDUMMY7','recent_180D_tongdunBlackDecisionDUMMYAccept','recent_180D_tongdunBlackDecision_bin_dummy2'],axis=1,inplace=True)
X_test_xgboost_with_bin_dummy.drop(['riskGradeDUMMY2','riskGrade_-9999'],axis=1,inplace=True)

# %%
X_train_xgboost_with_bin_dummy.shape,X_test_xgboost_with_bin_dummy.shape
# Out:
# ((10868, 221), (4659, 221))

# %% [markdown]
# ## 将所有数据存储到Data_path中

# %%
# 其中demo_xgb这个label很重要之后还会用到
save_data_to_pickle({
            'X_train_xgboost': X_train_xgboost_with_bin_dummy,
            'X_test_xgboost': X_test_xgboost_with_bin_dummy,
            'rebin_spec': rebin_spec_bin_adjusted_final,
            'bin_to_label': bin_to_label,
            'dummy_var_name_map': dummy_var_name_map}, Data_path,\
        '%s_XGBoost输出数据和分箱明细.pkl' % 'demo_xgb')

# %% [markdown]
# # 模型评估

# %% [markdown]
# ## XGboost参数设置

# %%
# 调参方法，可自行选择
xgbparams_selection_method = ['XGBExp', 'XGBRandom','XGBGrid']

# %%
# 随机调参时刻的相关参数
xgb_params_range = {
            'learning_rate': [0.03, 0.05,0.1,0.2],
            'max_depth': [2,3,4,5],
            'gamma': [0, 0.05, 0.1],
            'min_child_weight':[1,3],
            # 'subsample': np.linspace(0.4, 0.7, 3),
            # 'colsample_bytree': np.linspace(0.4, 0.7, 3),
        }

# %%
# 经验参数
xgb_param_experience = {
            'max_depth': 2,
            'min_samples_leaf ': 200,
             'eta': 0.1,
             'objective': 'binary:logistic',
             'subsample': 0.8,
             'colsample_bytree': 0.8,
             'gamma': 0,
             'silent': 0,
             'eval_metric':'auc'
        }

# %% [markdown]
# ## 拟合模型

# %%
sample_split_summary = ss.sample_split_summary(y_train,y_test)
sample_split_summary
# Out:
#    split  total   good   bad      rate      dist
# 0  train  10868   9846  1022  0.094038  0.699942
# 1   test   4659   4212   447  0.095943  0.300058
# 2    sum  15527  14058  1469  0.094609  1.000000

# %%
xgbmodel_obj = ml.XGBModel(var_dict, Data_path, Result_path,
                        'demo_xgb', y_train,
                        y_test=y_test,
                        params_selection_method=xgbparams_selection_method)

# %%
xgbmodel_obj.run(xgb_params_range, xgb_param_experience, xgb_select=False)
# Out:
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	train-auc:0.760122	test-auc:0.749936
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [10]	train-auc:0.824746	test-auc:0.804653
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [20]	train-auc:0.842379	test-auc:0.819342
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [30]	train-auc:0.856348	test-auc:0.829106
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [40]	train-auc:0.867705	test-auc:0.834592
# [11:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [50]	train-auc:0.8758	test-auc:0.83706
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [60]	train-auc:0.882778	test-auc:0.838971
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [70]	train-auc:0.889344	test-auc:0.840173
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [80]	train-auc:0.894992	test-auc:0.840695
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# ...
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [11:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3

# %% [markdown]
# ### 训练集和测试集拟合结果

# %%
plot_obj = ml.LogisticModel(var_dict=var_dict, y_train=y_train,
                                    y_test=y_test)

# %%
xgbparams_selection_method
# Out:
# ['XGBExp', 'XGBRandom', 'XGBGrid']

# %% [markdown]
# #### 查看XGBExp（经验参数）模型结果

# %%
model_result_exp = load_data_from_pickle(Data_path,
                '%s模型结果.pkl' % ('demo_xgb'+'XGBExp'))
plot_obj.plot_for_the_model(Result_path, model_result_exp, with_test=True)

# %% [markdown]
# #### 查看XGBExp（经验参数）对应的每一颗决策树的决策点

# %%
model_result_exp['model_final'].dump_model(Result_path+'/model_result_exp_trees.txt')

# %% [markdown]
# #### 查看XGBExp（经验参数）每一颗决策树对应的information和population

# %%
train_model_result_exp_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_exp\
                                                                         ,X_train_xgboost_with_bin_dummy,y_train,'y')

# %%
train_model_result_exp_leafs.head()
# Out:
#   var_name  leafNum  allNum  badNum      dist   badRate
# 0   tree_0        3     599     227  0.055116  0.378965
# 1   tree_0        4    3753     482  0.345326  0.128431
# 2   tree_0        5    6220     247  0.572322  0.039711
# 3   tree_0        6     296      66  0.027236  0.222973
# 4   tree_1        3     351     141  0.032297  0.401709

# %% [markdown]
# #### 查看XGBRandom（随机参数）模型结果

# %%
model_result_random = load_data_from_pickle(Data_path,
                '%s模型结果.pkl' % ('demo_xgb'+'XGBRandom'))
plot_obj.plot_for_the_model(Result_path, model_result_random, with_test=True)

# %% [markdown]
# #### 查看XGBRandom（随机参数）对应的每一颗决策树的决策点

# %%
model_result_random['model_final'].dump_model(Result_path+'/model_result_random_trees.txt')

# %% [markdown]
# #### 查看XGBRandom（随机参数）每一颗决策树对应的information和population

# %%
train_model_result_random_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_random\
                                                                         ,X_train_xgboost_with_bin_dummy,y_train,'y')

# %%
train_model_result_random_leafs.head(10)
# Out:
#   var_name  leafNum  allNum  badNum      dist   badRate
# 0   tree_0        7     320     182  0.029444  0.568750
# 1   tree_0        8     279      45  0.025672  0.161290
# 2   tree_0        9    2466     216  0.226905  0.087591
# 3   tree_0       10    1287     266  0.118421  0.206682
# 4   tree_0       11    6193     238  0.569838  0.038430
# 5   tree_0       12      27       9  0.002484  0.333333
# 6   tree_0       13     166      19  0.015274  0.114458
# 7   tree_0       14     130      47  0.011962  0.361538
# 8   tree_1        7     275      81  0.025304  0.294545
# 9   tree_1        8      76      60  0.006993  0.789474

# %% [markdown]
# #### 查看XGBGrid（网格参数）模型结果

# %%
model_result_grid = load_data_from_pickle(Data_path,
                '%s模型结果.pkl' % ('demo_xgb'+'XGBGrid'))
plot_obj.plot_for_the_model(Result_path, model_result_grid, with_test=True)

# %% [markdown]
# #### 查看XGBGrid（网格参数）对应的每一颗决策树的决策点

# %%
model_result_grid['model_final'].dump_model(Result_path+'/model_result_grid_trees.txt')

# %% [markdown]
# #### 查看XGBGrid（网格参数）每一颗决策树对应的information和population

# %%
train_model_result_grid_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_grid\
                                                                         ,X_train_xgboost_with_bin_dummy,y_train,'y')

# %%
train_model_result_grid_leafs.head(18)
# Out:
#    var_name  leafNum  allNum  badNum      dist   badRate
# 0    tree_0       15     181      76  0.016654  0.419890
# 1    tree_0       16     139     106  0.012790  0.762590
# 2    tree_0       17     242      31  0.022267  0.128099
# 3    tree_0       18      37      14  0.003404  0.378378
# 4    tree_0       19    2294     173  0.211078  0.075414
# 5    tree_0       20     172      43  0.015826  0.250000
# 6    tree_0       21    1090     193  0.100294  0.177064
# 7    tree_0       22     197      73  0.018127  0.370558
# 8    tree_0       23    4163      87  0.383051  0.020898
# 9    tree_0       24    2030     151  0.186787  0.074384
# 10   tree_0       25      13       2  0.001196  0.153846
# 11   tree_0       26      14       7  0.001288  0.500000
# 12   tree_0       27      29      10  0.002668  0.344828
# 13   tree_0       28     137       9  0.012606  0.065693
# 14   tree_0       29      14      11  0.001288  0.785714
# 15   tree_0       30     116      36  0.010674  0.310345
# 16   tree_1       12      15       6  0.001380  0.400000
# 17   tree_1       15      26      19  0.002392  0.730769

# %% [markdown]
# ## 查看decile和Runbook

# %% [markdown]
# ### 查看XGBExp模型decile

# %%
train_XGBExp_score = model_result_exp['p_train'].apply(mt.Performance().p_to_score)
test_XGBExp_score = model_result_exp['p_test'].apply(mt.Performance().p_to_score)

# %%
# 训练集
ks_decile_XGBExp_train = mt.Performance().calculate_ks_by_decile(train_XGBExp_score, np.array(y_train), 'decile', q=10)
ks_decile_XGBExp_train
# Out:
# col_0               分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (492.0, 566.0]  1085   875   210  0.193548  0.205479  0.088869
# 1        (52.0, 492.0]  1101   580   521  0.473206  0.509785  0.058907
# 2       (566.0, 619.0]  1087   986   101  0.092916  0.098826  0.100142
# 3       (619.0, 662.0]  1112  1051    61  0.054856  0.059687  0.106744
# 4       (662.0, 699.0]  1058  1000    58  0.054820  0.056751  0.101564
# 5       (699.0, 737.0]  1114  1090    24  0.021544  0.023483  0.110705
# 6       (737.0, 776.0]  1077  1051    26  0.024141  0.025440  0.106744
# 7       (776.0, 819.0]  1071  1063     8  0.007470  0.007828  0.107963
# 8       (819.0, 873.0]  1089  1078    11  0.010101  0.010763  0.109486
# 9      (873.0, 1096.0]  1074  1072     2  0.001862  0.001957  0.108877
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.205479  0.088869  0.1166             4.2
# 1      0.715264  0.147776  0.5675             1.1
# 2      0.814090  0.247918  0.5662             9.8
# 3      0.873777  0.354662  0.5191            17.2
# 4      0.930528  0.456226  0.4743            17.2
# 5      0.954012  0.566931  0.3871            45.4
# 6      0.979452  0.673675  0.3058            40.4
# 7      0.987280  0.781637  0.2056           132.9
# 8      0.998043  0.891123  0.1069            98.0
# 9      1.000000  1.000000  0.0000           536.0

# %%
# 测试集
point_bounds_XGBExp = mt.BinWoe().obtain_boundaries(ks_decile_XGBExp_train[u'分箱'])['cut_boundaries']
ks_decile_XGBExp_test = mt.Performance().calculate_ks_by_decile(test_XGBExp_score, np.array(y_test), 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBExp)
ks_decile_XGBExp_test
# Out:
# col_0              分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-inf, 492.0]  497   268   229  0.460765  0.512304  0.063628
# 1      (492.0, 566.0]  455   370    85  0.186813  0.190157  0.087844
# 2      (566.0, 619.0]  524   469    55  0.104962  0.123043  0.111349
# 3      (619.0, 662.0]  456   427    29  0.063596  0.064877  0.101377
# 4      (662.0, 699.0]  428   406    22  0.051402  0.049217  0.096391
# 5      (699.0, 737.0]  460   449    11  0.023913  0.024609  0.106600
# 6      (737.0, 776.0]  477   468     9  0.018868  0.020134  0.111111
# 7      (776.0, 819.0]  440   437     3  0.006818  0.006711  0.103751
# 8      (819.0, 873.0]  487   484     3  0.006160  0.006711  0.114910
# 9        (873.0, inf]  435   434     1  0.002299  0.002237  0.103039
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.512304  0.063628  0.4487             1.2
# 1      0.702461  0.151472  0.5510             4.4
# 2      0.825503  0.262821  0.5627             8.5
# 3      0.890380  0.364198  0.5262            14.7
# 4      0.939597  0.460589  0.4790            18.5
# 5      0.964206  0.567189  0.3970            40.8
# 6      0.984340  0.678300  0.3060            52.0
# 7      0.991051  0.782051  0.2090           145.7
# 8      0.997763  0.896961  0.1008           161.3
# 9      1.000000  1.000000 -0.0000           434.0

# %% [markdown]
# ### 生成XGBExp模型runbook

# %%
run_XGBExp_book = mt.Performance().calculate_ks_by_decile(pd.concat([train_XGBExp_score,test_XGBExp_score],join='outer'), np.array(pd.concat([y_train,y_test,],join='outer')), 'decile', \
                                                         q=20)

# %%
run_XGBExp_book
# Out:
# col_0               分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (425.0, 490.0]  784   539   245  0.312500  0.166780  0.038341
# 1        (43.0, 425.0]  777   287   490  0.630631  0.333560  0.020415
# 2       (490.0, 532.0]  775   593   182  0.234839  0.123894  0.042182
# 3       (532.0, 565.0]  779   653   126  0.161746  0.085773  0.046450
# 4       (565.0, 592.0]  790   703    87  0.110127  0.059224  0.050007
# 5       (592.0, 617.0]  764   699    65  0.085079  0.044248  0.049723
# 6       (617.0, 639.0]  771   722    49  0.063554  0.033356  0.051359
# 7       (639.0, 660.0]  784   741    43  0.054847  0.029272  0.052710
# 8       (660.0, 679.0]  775   732    43  0.055484  0.029272  0.052070
# 9       (679.0, 698.0]  770   729    41  0.053247  0.027910  0.051857
# 10      (698.0, 718.0]  800   785    15  0.018750  0.010211  0.055840
# 11      (718.0, 736.0]  755   737    18  0.023841  0.012253  0.052426
# 12      (736.0, 756.0]  804   784    20  0.024876  0.013615  0.055769
# 13      (756.0, 775.0]  765   748    17  0.022222  0.011572  0.053208
# 14      (775.0, 797.0]  775   766     9  0.011613  0.006127  0.054489
# 15      (797.0, 819.0]  774   772     2  0.002584  0.001361  0.054915
# 16      (819.0, 843.0]  758   749     9  0.011873  0.006127  0.053279
# 17      (843.0, 871.0]  775   770     5  0.006452  0.003404  0.054773
# 18      (871.0, 909.0]  778   775     3  0.003856  0.002042  0.055129
# 19     (909.0, 1096.0]  774   774     0  0.000000  0.000000  0.055058
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.166780  0.038341  0.1284        2.200000
# 1      0.500340  0.058757  0.4416        0.600000
# 2      0.624234  0.100939  0.5233        3.300000
# 3      0.710007  0.147389  0.5626        5.200000
# 4      0.769231  0.197397  0.5718        8.100000
# 5      0.813479  0.247119  0.5664       10.800000
# 6      0.846835  0.298478  0.5484       14.700000
# 7      0.876106  0.351188  0.5249       17.200000
# 8      0.905378  0.403258  0.5021       17.000000
# 9      0.933288  0.455115  0.4782       17.800000
# 10     0.943499  0.510955  0.4325       52.300000
# 11     0.955752  0.563380  0.3924       40.900000
# 12     0.969367  0.619149  0.3502       39.200000
# 13     0.980939  0.672357  0.3086       44.000000
# 14     0.987066  0.726846  0.2602       85.100000
# 15     0.988428  0.781761  0.2067      386.000000
# 16     0.994554  0.835041  0.1595       83.200000
# 17     0.997958  0.889814  0.1081      154.000000
# 18     1.000000  0.944942  0.0551      258.300000
# 19     1.000000  1.000000 -0.0000             inf

# %% [markdown]
# ### XGBRandom模型decile

# %%
train_XGBRandom_score = model_result_random['p_train'].apply(mt.Performance().p_to_score)
test_XGBRandom_score = model_result_random['p_test'].apply(mt.Performance().p_to_score)

# %%
# 训练集
ks_decile_XGBRandom_train = mt.Performance().calculate_ks_by_decile(train_XGBRandom_score, np.array(y_train), 'decile', q=10)
ks_decile_XGBRandom_train
# Out:
# col_0               分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-25.0, 492.0]  1095   543   552  0.504110  0.540117  0.055149
# 1       (492.0, 570.0]  1085   876   209  0.192627  0.204501  0.088970
# 2       (570.0, 622.0]  1082   984    98  0.090573  0.095890  0.099939
# 3       (622.0, 665.0]  1121  1051    70  0.062444  0.068493  0.106744
# 4       (665.0, 699.0]  1060  1022    38  0.035849  0.037182  0.103798
# 5       (699.0, 738.0]  1084  1062    22  0.020295  0.021526  0.107861
# 6       (738.0, 776.0]  1086  1072    14  0.012891  0.013699  0.108877
# 7       (776.0, 818.0]  1089  1075    14  0.012856  0.013699  0.109181
# 8       (818.0, 872.0]  1086  1083     3  0.002762  0.002935  0.109994
# 9      (872.0, 1054.0]  1080  1078     2  0.001852  0.001957  0.109486
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.540117  0.055149  0.4850             1.0
# 1      0.744618  0.144119  0.6005             4.2
# 2      0.840509  0.244059  0.5965            10.0
# 3      0.909002  0.350802  0.5582            15.0
# 4      0.946184  0.454601  0.4916            26.9
# 5      0.967710  0.562462  0.4052            48.3
# 6      0.981409  0.671339  0.3101            76.6
# 7      0.995108  0.780520  0.2146            76.8
# 8      0.998043  0.890514  0.1075           361.0
# 9      1.000000  1.000000  0.0000           539.0

# %%
# 测试集
point_bounds_XGBRandom = mt.BinWoe().obtain_boundaries(ks_decile_XGBRandom_train[u'分箱'])['cut_boundaries']
ks_decile_XGBRandom_test = mt.Performance().calculate_ks_by_decile(test_XGBRandom_score, np.array(y_test), 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBRandom)
ks_decile_XGBRandom_test
# Out:
# col_0              分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-inf, 492.0]  480   237   243  0.506250  0.543624  0.056268
# 1      (492.0, 570.0]  485   398    87  0.179381  0.194631  0.094492
# 2      (570.0, 622.0]  504   457    47  0.093254  0.105145  0.108500
# 3      (622.0, 665.0]  456   421    35  0.076754  0.078300  0.099953
# 4      (665.0, 699.0]  404   391    13  0.032178  0.029083  0.092830
# 5      (699.0, 738.0]  489   483     6  0.012270  0.013423  0.114672
# 6      (738.0, 776.0]  466   455    11  0.023605  0.024609  0.108025
# 7      (776.0, 818.0]  454   452     2  0.004405  0.004474  0.107312
# 8      (818.0, 872.0]  484   481     3  0.006198  0.006711  0.114198
# 9        (872.0, inf]  437   437     0  0.000000  0.000000  0.103751
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.543624  0.056268  0.4874        1.000000
# 1      0.738255  0.150760  0.5875        4.600000
# 2      0.843400  0.259259  0.5841        9.700000
# 3      0.921700  0.359212  0.5625       12.000000
# 4      0.950783  0.452042  0.4987       30.100000
# 5      0.964206  0.566714  0.3975       80.500000
# 6      0.988814  0.674739  0.3141       41.400000
# 7      0.993289  0.782051  0.2112      226.000000
# 8      1.000000  0.896249  0.1038      160.300000
# 9      1.000000  1.000000  0.0000             inf

# %% [markdown]
# ### 生成XGBRandom模型runbook

# %%
run_XGBRandom_book = mt.Performance().calculate_ks_by_decile(pd.concat([train_XGBRandom_score,test_XGBRandom_score],join='outer'), np.array(pd.concat([y_train,y_test,],join='outer')), 'decile', \
                                                         q=20)

# %%
run_XGBRandom_book
# Out:
# col_0               分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-29.0, 423.0]  780   247   533  0.683333  0.362832  0.017570
# 1       (423.0, 491.0]  781   521   260  0.332907  0.176991  0.037061
# 2       (491.0, 534.0]  773   591   182  0.235446  0.123894  0.042040
# 3       (534.0, 569.0]  791   679   112  0.141593  0.076242  0.048300
# 4       (569.0, 597.0]  777   702    75  0.096525  0.051055  0.049936
# 5       (597.0, 620.0]  761   693    68  0.089356  0.046290  0.049296
# 6       (620.0, 643.0]  799   745    54  0.067584  0.036760  0.052995
# 7       (643.0, 663.0]  758   709    49  0.064644  0.033356  0.050434
# 8       (663.0, 681.0]  783   748    35  0.044700  0.023826  0.053208
# 9       (681.0, 699.0]  769   745    24  0.031209  0.016338  0.052995
# 10      (699.0, 718.0]  773   758    15  0.019405  0.010211  0.053919
# 11      (718.0, 738.0]  800   787    13  0.016250  0.008850  0.055982
# 12      (738.0, 756.0]  767   756    11  0.014342  0.007488  0.053777
# 13      (756.0, 776.0]  785   771    14  0.017834  0.009530  0.054844
# 14      (776.0, 796.0]  764   754    10  0.013089  0.006807  0.053635
# 15      (796.0, 818.0]  779   773     6  0.007702  0.004084  0.054986
# 16      (818.0, 842.0]  760   756     4  0.005263  0.002723  0.053777
# 17      (842.0, 871.0]  784   782     2  0.002551  0.001361  0.055627
# 18      (871.0, 907.0]  777   775     2  0.002574  0.001361  0.055129
# 19     (907.0, 1054.0]  766   766     0  0.000000  0.000000  0.054489
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.362832  0.017570  0.3453        0.500000
# 1      0.539823  0.054631  0.4852        2.000000
# 2      0.663717  0.096671  0.5670        3.200000
# 3      0.739959  0.144971  0.5950        6.100000
# 4      0.791014  0.194907  0.5961        9.400000
# 5      0.837304  0.244203  0.5931       10.200000
# 6      0.874064  0.297197  0.5769       13.800000
# 7      0.907420  0.347631  0.5598       14.500000
# 8      0.931246  0.400839  0.5304       21.400000
# 9      0.947583  0.453834  0.4937       31.000000
# 10     0.957794  0.507754  0.4500       50.500000
# 11     0.966644  0.563736  0.4029       60.500000
# 12     0.974132  0.617513  0.3566       68.700000
# 13     0.983662  0.672357  0.3113       55.100000
# 14     0.990470  0.725992  0.2645       75.400000
# 15     0.994554  0.780979  0.2136      128.800000
# 16     0.997277  0.834756  0.1625      189.000000
# 17     0.998639  0.890383  0.1083      391.000000
# 18     1.000000  0.945511  0.0545      387.500000
# 19     1.000000  1.000000 -0.0000             inf

# %% [markdown]
# ### XGBGrid模型decile

# %%
train_XGBGrid_score = model_result_grid['p_train'].apply(mt.Performance().p_to_score)
test_XGBGrid_score = model_result_grid['p_test'].apply(mt.Performance().p_to_score)

# %%
# 训练集
ks_decile_XGBGrid_train = mt.Performance().calculate_ks_by_decile(train_XGBGrid_score, np.array(y_train), 'decile', q=10)
ks_decile_XGBGrid_train
# Out:
# col_0              分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (28.0, 495.0]  1096   534   562  0.512774  0.549902  0.054235
# 1      (495.0, 572.0]  1087   873   214  0.196872  0.209393  0.088665
# 2      (572.0, 621.0]  1096  1002    94  0.085766  0.091977  0.101767
# 3      (621.0, 660.0]  1078  1019    59  0.054731  0.057730  0.103494
# 4      (660.0, 694.0]  1083  1047    36  0.033241  0.035225  0.106338
# 5      (694.0, 728.0]  1100  1072    28  0.025455  0.027397  0.108877
# 6      (728.0, 763.0]  1086  1069    17  0.015654  0.016634  0.108572
# 7      (763.0, 801.0]  1081  1074     7  0.006475  0.006849  0.109080
# 8      (801.0, 844.0]  1076  1071     5  0.004647  0.004892  0.108775
# 9      (844.0, 949.0]  1085  1085     0  0.000000  0.000000  0.110197
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.549902  0.054235  0.4957        1.000000
# 1      0.759295  0.142901  0.6164        4.100000
# 2      0.851272  0.244668  0.6066       10.700000
# 3      0.909002  0.348162  0.5608       17.300000
# 4      0.944227  0.454499  0.4897       29.100000
# 5      0.971624  0.563376  0.4082       38.300000
# 6      0.988258  0.671948  0.3163       62.900000
# 7      0.995108  0.781028  0.2141      153.400000
# 8      1.000000  0.889803  0.1102      214.200000
# 9      1.000000  1.000000  0.0000             inf

# %%
# 测试集
point_bounds_XGBGrid = mt.BinWoe().obtain_boundaries(ks_decile_XGBGrid_train[u'分箱'])['cut_boundaries']
ks_decile_XGBGrid_test = mt.Performance().calculate_ks_by_decile(test_XGBGrid_score, np.array(y_test), 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBGrid)
ks_decile_XGBGrid_test
# Out:
# col_0              分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-inf, 495.0]  481   236   245  0.509356  0.548098  0.056030
# 1      (495.0, 572.0]  503   415    88  0.174950  0.196868  0.098528
# 2      (572.0, 621.0]  470   425    45  0.095745  0.100671  0.100902
# 3      (621.0, 660.0]  494   459    35  0.070850  0.078300  0.108974
# 4      (660.0, 694.0]  424   412    12  0.028302  0.026846  0.097816
# 5      (694.0, 728.0]  438   430     8  0.018265  0.017897  0.102089
# 6      (728.0, 763.0]  492   485     7  0.014228  0.015660  0.115147
# 7      (763.0, 801.0]  437   431     6  0.013730  0.013423  0.102327
# 8      (801.0, 844.0]  497   496     1  0.002012  0.002237  0.117759
# 9        (844.0, inf]  423   423     0  0.000000  0.000000  0.100427
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.548098  0.056030  0.4921        1.000000
# 1      0.744966  0.154558  0.5904        4.700000
# 2      0.845638  0.255461  0.5902        9.400000
# 3      0.923937  0.364435  0.5595       13.100000
# 4      0.950783  0.462251  0.4885       34.300000
# 5      0.968680  0.564340  0.4043       53.800000
# 6      0.984340  0.679487  0.3049       69.300000
# 7      0.997763  0.781814  0.2159       71.800000
# 8      1.000000  0.899573  0.1004      496.000000
# 9      1.000000  1.000000  0.0000             inf

# %% [markdown]
# ### 生成XGBGrid模型runbook

# %%
run_XGBGrid_book = mt.Performance().calculate_ks_by_decile(pd.concat([train_XGBGrid_score,test_XGBGrid_score],join='outer'), np.array(pd.concat([y_train,y_test,],join='outer')), 'decile', \
                                                         q=20)

# %%
run_XGBGrid_book
# Out:
# col_0              分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比  \
# 0       (-9.0, 429.0]  777   231   546  0.702703  0.371681  0.016432
# 1      (429.0, 494.0]  781   523   258  0.330346  0.175630  0.037203
# 2      (494.0, 537.0]  792   605   187  0.236111  0.127297  0.043036
# 3      (537.0, 570.0]  776   665   111  0.143041  0.075562  0.047304
# 4      (570.0, 596.0]  777   698    79  0.101673  0.053778  0.049651
# 5      (596.0, 619.0]  761   699    62  0.081472  0.042206  0.049723
# 6      (619.0, 639.0]  774   728    46  0.059432  0.031314  0.051785
# 7      (639.0, 658.0]  785   737    48  0.061146  0.032675  0.052426
# 8      (658.0, 677.0]  798   770    28  0.035088  0.019061  0.054773
# 9      (677.0, 693.0]  744   721    23  0.030914  0.015657  0.051288
# 10     (693.0, 710.0]  802   782    20  0.024938  0.013615  0.055627
# 11     (710.0, 728.0]  783   765    18  0.022989  0.012253  0.054417
# 12     (728.0, 746.0]  782   771    11  0.014066  0.007488  0.054844
# 13     (746.0, 762.0]  752   740    12  0.015957  0.008169  0.052639
# 14     (762.0, 782.0]  798   788    10  0.012531  0.006807  0.056053
# 15     (782.0, 801.0]  764   760     4  0.005236  0.002723  0.054062
# 16     (801.0, 820.0]  763   760     3  0.003932  0.002042  0.054062
# 17     (820.0, 843.0]  784   781     3  0.003827  0.002042  0.055556
# 18     (843.0, 871.0]  764   764     0  0.000000  0.000000  0.054346
# 19     (871.0, 949.0]  770   770     0  0.000000  0.000000  0.054773
#
# col_0   累积Bad占比  累积Good占比      KS  odds(good:bad)
# 0      0.371681  0.016432  0.3552        0.400000
# 1      0.547311  0.053635  0.4937        2.000000
# 2      0.674609  0.096671  0.5779        3.200000
# 3      0.750170  0.143975  0.6062        6.000000
# 4      0.803948  0.193626  0.6103        8.800000
# 5      0.846154  0.243349  0.6028       11.300000
# 6      0.877468  0.295134  0.5823       15.800000
# 7      0.910143  0.347560  0.5626       15.400000
# 8      0.929204  0.402333  0.5269       27.500000
# 9      0.944860  0.453621  0.4912       31.300000
# 10     0.958475  0.509247  0.4492       39.100000
# 11     0.970728  0.563665  0.4071       42.500000
# 12     0.978216  0.618509  0.3597       70.100000
# 13     0.986385  0.671148  0.3152       61.700000
# 14     0.993193  0.727202  0.2660       78.800000
# 15     0.995916  0.781263  0.2147      190.000000
# 16     0.997958  0.835325  0.1626      253.300000
# 17     1.000000  0.890881  0.1091      260.300000
# 18     1.000000  0.945227  0.0548             inf
# 19     1.000000  1.000000  0.0000             inf

# %% [markdown]
# # OOT数据验证（如果没有OOT数据可以不做这一步）

# %%
data_OOT = load_data_from_pickle(Data_path,'data_OOT1.pkl')

# %%
data_OOT['y'] = np.where(data_OOT.d_y_hismaxdpd>=30,1,0)

# %%
# 设置数据集的唯一标识
data_OOT.index = data_OOT.userid

# %%
# 建议使用这种方法，可以避免varchar类型的变量填充错误等问题
data_OOT_final = mu.process_missing(data_OOT, var_dict, known_missing={-9999999: -8887})
# Out:
# Warnings: downflag variable is not in downflagmap provided for performance
# Warnings: downflag variable is not in downflagmap provided for payment
# Warnings: downflag variable is not in downflagmap provided for DEVICE
# Warnings: downflag variable is not in downflagmap provided for APPLICATION
# Warnings: downflag variable is not in downflagmap provided for REPAY_DETAIL
# Warnings: downflag variable is not in downflagmap provided for TONGDUN_DETAIL
# Warnings: downflag variable is not in downflagmap provided for model_bScore
# Warnings: downflag variable is not in downflagmap provided for ML

# %%
data_OOT_final = mu.convert_right_data_type(data_OOT_final, var_dict)[0]

# %% [markdown]
# ## 找出不同的segment人群

# %%
data_OOT.tag.value_counts()
# Out:
# yzd_wyq    17581
# wzd_wqx    15467
# yzd_yyq    14391
# wzd_yqx      995
# Name: tag, dtype: int64

# %%
userid_yzd_wyq_list = list(data_OOT[data_OOT.tag == 'yzd_wyq'].userid)
userid_yzd_yyq_list = list(data_OOT[data_OOT.tag == 'yzd_yyq'].userid)
userid_wzd_list = list(data_OOT[data_OOT.tag.isin(['wzd_wqx','wzd_yqx'])].userid)

# %%
data_OOT_final_selected = data_OOT_final[selected_final]
X_cat_OOT = bin_obj.convert_to_category(data_OOT_final_selected, var_dict, rebin_spec_bin_adjusted_final)

# %%
data_OOT_final_xgboost = mt.BinWoe().apply_xgboost_data_derive(data_OOT_final_selected,
                                var_dict, rebin_spec_bin_adjusted_final, bin_to_label)

# %%
X_OOT_xgboost_with_bin_dummy = bin_obj.convert_xgboost_rebins_to_dummy(data_OOT_final_xgboost,X_cat_OOT\
                                                                        ,dummy_var_name_map,is_apply=True)

# %%
X_OOT_xgboost_with_bin_dummy.shape
# Out:
# (50000, 221)

# %% [markdown]
# ## 有在贷有逾期用户的runbook

# %% [markdown]
# ### 将有在贷有逾期的人找出来

# %%
data_OOT_final_xgboost_yzd_yyq = X_OOT_xgboost_with_bin_dummy\
[X_OOT_xgboost_with_bin_dummy.index.isin(userid_yzd_yyq_list)]

# %% [markdown]
# ### 使用XGBExp模型结果对OOT打分

# %%
# 由于建模时候apollo_osBalanceSelfProduct有-8887取值，但是OOT中没有，因此出现了dummy的缺失
data_OOT_final_xgboost_yzd_yyq['apollo_osBalanceSelfProduct_bin_dummy2'] = 0

# %%
data_OOT_XGBExp_p_score = mt.Performance().calculate_score_by_xgb_model_result\
(data_OOT_final_xgboost_yzd_yyq, model_result_exp)

# %%
data_OOT_XGBExp = pd.merge(data_OOT,data_OOT_XGBExp_p_score\
                           ,left_index=True,right_index=True)

# %%
# 生成runbook
run_book_yzd_yyq_XGBExp_OOT = mt.Performance().calculate_ks_by_decile(data_OOT_XGBExp.xgbScore\
,data_OOT_XGBExp.y, 'decile', q=20)
run_book_yzd_yyq_XGBExp_OOT
# Out:
# y                分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0    (230.0, 475.0]  721   459   262  0.363384  0.213878  0.034863  0.213878
# 1    (475.0, 523.0]  730   562   168  0.230137  0.137143  0.042686  0.351020
# 2    (523.0, 556.0]  708   591   117  0.165254  0.095510  0.044888  0.446531
# 3    (556.0, 582.0]  749   634   115  0.153538  0.093878  0.048154  0.540408
# 4    (582.0, 603.0]  718   639    79  0.110028  0.064490  0.048534  0.604898
# 5    (603.0, 622.0]  692   623    69  0.099711  0.056327  0.047319  0.661224
# 6    (622.0, 641.0]  740   677    63  0.085135  0.051429  0.051420  0.712653
# 7    (641.0, 659.0]  735   683    52  0.070748  0.042449  0.051876  0.755102
# 8    (659.0, 675.0]  732   683    49  0.066940  0.040000  0.051876  0.795102
# 9    (675.0, 691.0]  695   659    36  0.051799  0.029388  0.050053  0.824490
# 10   (691.0, 708.0]  710   670    40  0.056338  0.032653  0.050889  0.857143
# 11   (708.0, 725.0]  733   698    35  0.047749  0.028571  0.053015  0.885714
# 12   (725.0, 742.0]  732   710    22  0.030055  0.017959  0.053927  0.903673
# 13   (742.0, 759.0]  706   678    28  0.039660  0.022857  0.051496  0.926531
# 14   (759.0, 779.0]  700   673    27  0.038571  0.022041  0.051117  0.948571
# 15   (779.0, 803.0]  725   701    24  0.033103  0.019592  0.053243  0.968163
# 16   (803.0, 829.0]  708   694    14  0.019774  0.011429  0.052712  0.979592
# 17   (829.0, 859.0]  737   723    14  0.018996  0.011429  0.054914  0.991020
# 18   (859.0, 897.0]  704   694    10  0.014205  0.008163  0.052712  0.999184
# 19  (897.0, 1065.0]  716   715     1  0.001397  0.000816  0.054307  1.000000
#
# y   累积Good占比      KS  odds(good:bad)
# 0   0.034863  0.1790             1.8
# 1   0.077548  0.2735             3.3
# 2   0.122437  0.3241             5.1
# 3   0.170591  0.3698             5.5
# 4   0.219125  0.3858             8.1
# 5   0.266444  0.3948             9.0
# 6   0.317864  0.3948            10.7
# 7   0.369740  0.3854            13.1
# 8   0.421616  0.3735            13.9
# 9   0.471669  0.3528            18.3
# 10  0.522558  0.3346            16.8
# 11  0.575573  0.3101            19.9
# 12  0.629500  0.2742            32.3
# 13  0.680997  0.2455            24.2
# 14  0.732113  0.2165            24.9
# 15  0.785356  0.1828            29.2
# 16  0.838068  0.1415            49.6
# 17  0.892982  0.0980            51.6
# 18  0.945693  0.0535            69.4
# 19  1.000000  0.0000           715.0

# %%
# 生成decile
ks_decile_OOT_XGBExp_yzd_yyq = mt.Performance().calculate_ks_by_decile(data_OOT_XGBExp.xgbScore\
                                                         , data_OOT_XGBExp.y, 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBExp)
ks_decile_OOT_XGBExp_yzd_yyq
# Out:
# y              分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0   (-inf, 492.0]   947   632   315  0.332629  0.257143  0.048002  0.257143
# 1  (492.0, 566.0]  1507  1226   281  0.186463  0.229388  0.093119  0.486531
# 2  (566.0, 619.0]  1762  1555   207  0.117480  0.168980  0.118107  0.655510
# 3  (619.0, 662.0]  1712  1578   134  0.078271  0.109388  0.119854  0.764898
# 4  (662.0, 699.0]  1604  1517    87  0.054239  0.071020  0.115221  0.835918
# 5  (699.0, 737.0]  1636  1559    77  0.047066  0.062857  0.118411  0.898776
# 6  (737.0, 776.0]  1543  1485    58  0.037589  0.047347  0.112791  0.946122
# 7  (776.0, 819.0]  1253  1215    38  0.030327  0.031020  0.092283  0.977143
# 8  (819.0, 873.0]  1316  1297    19  0.014438  0.015510  0.098511  0.992653
# 9    (873.0, inf]  1111  1102     9  0.008101  0.007347  0.083700  1.000000
#
# y  累积Good占比      KS  odds(good:bad)
# 0  0.048002  0.2091             2.0
# 1  0.141121  0.3454             4.4
# 2  0.259228  0.3963             7.5
# 3  0.379082  0.3858            11.8
# 4  0.494304  0.3416            17.4
# 5  0.612715  0.2861            20.2
# 6  0.725505  0.2206            25.6
# 7  0.817788  0.1594            32.0
# 8  0.916300  0.0764            68.3
# 9  1.000000 -0.0000           122.4

# %% [markdown]
# ### 使用XGBRandom模型结果对OOT打分

# %%
data_OOT_XGBRandom_p_score = mt.Performance().calculate_score_by_xgb_model_result\
(data_OOT_final_xgboost_yzd_yyq, model_result_random)
# 将打分数据与y数据进行合并
data_OOT_XGBRandom = pd.merge(data_OOT,data_OOT_XGBRandom_p_score\
                           ,left_index=True,right_index=True)

# %%
# 生成runbook
run_book_yzd_yyq_XGBRandom_OOT = mt.Performance().calculate_ks_by_decile(data_OOT_XGBRandom.xgbScore\
,data_OOT_XGBRandom.y, 'decile', q=20)
run_book_yzd_yyq_XGBRandom_OOT
# Out:
# y                分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0    (153.0, 474.0]  725   456   269  0.371034  0.219592  0.034635  0.219592
# 1    (474.0, 521.0]  721   545   176  0.244105  0.143673  0.041395  0.363265
# 2    (521.0, 554.0]  727   611   116  0.159560  0.094694  0.046407  0.457959
# 3    (554.0, 581.0]  727   613   114  0.156809  0.093061  0.046559  0.551020
# 4    (581.0, 603.0]  707   620    87  0.123055  0.071020  0.047091  0.622041
# 5    (603.0, 622.0]  715   655    60  0.083916  0.048980  0.049749  0.671020
# 6    (622.0, 639.0]  722   659    63  0.087258  0.051429  0.050053  0.722449
# 7    (639.0, 656.0]  739   693    46  0.062246  0.037551  0.052636  0.760000
# 8    (656.0, 671.0]  701   660    41  0.058488  0.033469  0.050129  0.793469
# 9    (671.0, 687.0]  739   693    46  0.062246  0.037551  0.052636  0.831020
# 10   (687.0, 703.0]  692   660    32  0.046243  0.026122  0.050129  0.857143
# 11   (703.0, 718.0]  744   704    40  0.053763  0.032653  0.053471  0.889796
# 12   (718.0, 733.0]  732   703    29  0.039617  0.023673  0.053395  0.913469
# 13   (733.0, 749.0]  689   665    24  0.034833  0.019592  0.050509  0.933061
# 14   (749.0, 769.0]  729   701    28  0.038409  0.022857  0.053243  0.955918
# 15   (769.0, 791.0]  710   689    21  0.029577  0.017143  0.052332  0.973061
# 16   (791.0, 818.0]  734   720    14  0.019074  0.011429  0.054686  0.984490
# 17   (818.0, 848.0]  708   699     9  0.012712  0.007347  0.053091  0.991837
# 18   (848.0, 889.0]  712   704     8  0.011236  0.006531  0.053471  0.998367
# 19  (889.0, 1037.0]  718   716     2  0.002786  0.001633  0.054383  1.000000
#
# y   累积Good占比      KS  odds(good:bad)
# 0   0.034635  0.1850             1.7
# 1   0.076029  0.2872             3.1
# 2   0.122437  0.3355             5.3
# 3   0.168996  0.3820             5.4
# 4   0.216087  0.4060             7.1
# 5   0.265836  0.4052            10.9
# 6   0.315889  0.4066            10.5
# 7   0.368525  0.3915            15.1
# 8   0.418654  0.3748            16.1
# 9   0.471290  0.3597            15.1
# 10  0.521419  0.3357            20.6
# 11  0.574890  0.3149            17.6
# 12  0.628285  0.2852            24.2
# 13  0.678794  0.2543            27.7
# 14  0.732037  0.2239            25.0
# 15  0.784369  0.1887            32.8
# 16  0.839055  0.1454            51.4
# 17  0.892146  0.0997            77.7
# 18  0.945617  0.0527            88.0
# 19  1.000000  0.0000           358.0

# %%
# 生成decile
ks_decile_OOT_XGBRandom_yzd_yyq = mt.Performance().calculate_ks_by_decile(data_OOT_XGBRandom.xgbScore\
                                                         , data_OOT_XGBRandom.y, 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBRandom)
ks_decile_OOT_XGBRandom_yzd_yyq
# Out:
# y              分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0   (-inf, 492.0]   956   631   325  0.339958  0.265306  0.047926  0.265306
# 1  (492.0, 570.0]  1631  1326   305  0.187002  0.248980  0.100714  0.514286
# 2  (570.0, 622.0]  1735  1543   192  0.110663  0.156735  0.117196  0.671020
# 3  (622.0, 665.0]  1860  1729   131  0.070430  0.106939  0.131323  0.777959
# 4  (665.0, 699.0]  1591  1501    90  0.056568  0.073469  0.114006  0.851429
# 5  (699.0, 738.0]  1836  1755    81  0.044118  0.066122  0.133298  0.917551
# 6  (738.0, 776.0]  1441  1387    54  0.037474  0.044082  0.105347  0.961633
# 7  (776.0, 818.0]  1203  1175    28  0.023275  0.022857  0.089245  0.984490
# 8  (818.0, 872.0]  1161  1146    15  0.012920  0.012245  0.087042  0.996735
# 9    (872.0, inf]   977   973     4  0.004094  0.003265  0.073902  1.000000
#
# y  累积Good占比      KS  odds(good:bad)
# 0  0.047926  0.2174             1.9
# 1  0.148640  0.3656             4.3
# 2  0.265836  0.4052             8.0
# 3  0.397159  0.3808            13.2
# 4  0.511165  0.3403            16.7
# 5  0.644463  0.2731            21.7
# 6  0.749810  0.2118            25.7
# 7  0.839055  0.1454            42.0
# 8  0.926098  0.0706            76.4
# 9  1.000000  0.0000           243.2

# %% [markdown]
# ### 使用XGBGrid模型结果对OOT打分

# %%
data_OOT_XGBGrid_p_score = mt.Performance().calculate_score_by_xgb_model_result\
(data_OOT_final_xgboost_yzd_yyq, model_result_grid)
# 将打分数据与y数据进行合并
# 将打分数据与y数据进行合并
data_OOT_XGBGrid = pd.merge(data_OOT,data_OOT_XGBGrid_p_score\
                           ,left_index=True,right_index=True)

# %%
# 生成runbook
run_book_yzd_yyq_XGBGrid_OOT = mt.Performance().calculate_ks_by_decile(data_OOT_XGBGrid.xgbScore\
,data_OOT_XGBGrid.y, 'decile', q=20)
run_book_yzd_yyq_XGBGrid_OOT
# Out:
# y               分箱  样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0   (225.0, 481.0]  735   469   266  0.361905  0.217143  0.035622  0.217143
# 1   (481.0, 527.0]  717   540   177  0.246862  0.144490  0.041015  0.361633
# 2   (527.0, 557.0]  713   591   122  0.171108  0.099592  0.044888  0.461224
# 3   (557.0, 582.0]  715   611   104  0.145455  0.084898  0.046407  0.546122
# 4   (582.0, 603.0]  741   649    92  0.124157  0.075102  0.049294  0.621224
# 5   (603.0, 621.0]  706   629    77  0.109065  0.062857  0.047775  0.684082
# 6   (621.0, 637.0]  728   668    60  0.082418  0.048980  0.050737  0.733061
# 7   (637.0, 653.0]  755   703    52  0.068874  0.042449  0.053395  0.775510
# 8   (653.0, 666.0]  681   645    36  0.052863  0.029388  0.048990  0.804898
# 9   (666.0, 681.0]  755   719    36  0.047682  0.029388  0.054610  0.834286
# 10  (681.0, 695.0]  720   674    46  0.063889  0.037551  0.051192  0.871837
# 11  (695.0, 707.0]  679   653    26  0.038292  0.021224  0.049597  0.893061
# 12  (707.0, 721.0]  748   720    28  0.037433  0.022857  0.054686  0.915918
# 13  (721.0, 735.0]  685   655    30  0.043796  0.024490  0.049749  0.940408
# 14  (735.0, 752.0]  727   708    19  0.026135  0.015510  0.053775  0.955918
# 15  (752.0, 772.0]  732   712    20  0.027322  0.016327  0.054079  0.972245
# 16  (772.0, 794.0]  698   682    16  0.022923  0.013061  0.051800  0.985306
# 17  (794.0, 821.0]  725   713    12  0.016552  0.009796  0.054155  0.995102
# 18  (821.0, 857.0]  720   715     5  0.006944  0.004082  0.054307  0.999184
# 19  (857.0, 941.0]  711   710     1  0.001406  0.000816  0.053927  1.000000
#
# y   累积Good占比      KS  odds(good:bad)
# 0   0.035622  0.1815             1.8
# 1   0.076637  0.2850             3.1
# 2   0.121525  0.3397             4.8
# 3   0.167933  0.3782             5.9
# 4   0.217226  0.4040             7.1
# 5   0.265001  0.4191             8.2
# 6   0.315738  0.4173            11.1
# 7   0.369133  0.4064            13.5
# 8   0.418122  0.3868            17.9
# 9   0.472733  0.3616            20.0
# 10  0.523925  0.3479            14.7
# 11  0.573523  0.3195            25.1
# 12  0.628209  0.2877            25.7
# 13  0.677958  0.2624            21.8
# 14  0.731733  0.2242            37.3
# 15  0.785812  0.1864            35.6
# 16  0.837612  0.1477            42.6
# 17  0.891767  0.1033            59.4
# 18  0.946073  0.0531           143.0
# 19  1.000000  0.0000           710.0

# %%
# 生成decile
ks_decile_OOT_XGBGrid_yzd_yyq = mt.Performance().calculate_ks_by_decile(data_OOT_XGBGrid.xgbScore\
                                                         , data_OOT_XGBGrid.y, 'decile', \
                                                         manual_cut_bounds=point_bounds_XGBGrid)
ks_decile_OOT_XGBGrid_yzd_yyq
# Out:
# y              分箱   样本数  好样本数  坏样本数       逾期率   Bad分布占比  Good分布占比   累积Bad占比  \
# 0   (-inf, 495.0]   901   589   312  0.346282  0.254694  0.044736  0.254694
# 1  (495.0, 572.0]  1668  1355   313  0.187650  0.255510  0.102917  0.510204
# 2  (572.0, 621.0]  1758  1545   213  0.121160  0.173878  0.117348  0.684082
# 3  (621.0, 660.0]  1847  1717   130  0.070384  0.106122  0.130412  0.790204
# 4  (660.0, 694.0]  1735  1636    99  0.057061  0.080816  0.124259  0.871020
# 5  (694.0, 728.0]  1843  1775    68  0.036896  0.055510  0.134817  0.926531
# 6  (728.0, 763.0]  1484  1434    50  0.033693  0.040816  0.108917  0.967347
# 7  (763.0, 801.0]  1210  1183    27  0.022314  0.022041  0.089853  0.989388
# 8  (801.0, 844.0]   994   985     9  0.009054  0.007347  0.074814  0.996735
# 9    (844.0, inf]   951   947     4  0.004206  0.003265  0.071928  1.000000
#
# y  累积Good占比      KS  odds(good:bad)
# 0  0.044736  0.2100             1.9
# 1  0.147653  0.3626             4.3
# 2  0.265001  0.4191             7.3
# 3  0.395412  0.3948            13.2
# 4  0.519672  0.3513            16.5
# 5  0.654489  0.2720            26.1
# 6  0.763406  0.2039            28.7
# 7  0.853258  0.1361            43.8
# 8  0.928072  0.0687           109.4
# 9  1.000000  0.0000           236.8

# %% [markdown]
# # OOT PSI以及ranking验证

# %%
# 合并y数据为后续统计做准备
data_OOT_final_xgboost_yzd_yyq_with_y = pd.merge(data_OOT_final_xgboost_yzd_yyq\
                                                 ,data_OOT[['y']],left_index=True,right_index=True)

# %% [markdown]
# ## XGBExp模型分的psi

# %%
score_ranking_train_vs_oot_XGBExp = mt.Performance().score_ranking_psi_train_vs_oot\
(ks_decile_XGBExp_train,ks_decile_OOT_XGBExp_yzd_yyq)

# %%
score_ranking_train_vs_oot_XGBExp
# Out:
#                 分箱  train_set样本量  train_set逾期率  train_set分布占比  OOT_set样本量  \
# 0   (492.0, 566.0]          1085      0.193548       0.099834         947
# 1    (52.0, 492.0]          1101      0.473206       0.101307        1507
# 2   (566.0, 619.0]          1087      0.092916       0.100018        1762
# 3   (619.0, 662.0]          1112      0.054856       0.102319        1712
# 4   (662.0, 699.0]          1058      0.054820       0.097350        1604
# 5   (699.0, 737.0]          1114      0.021544       0.102503        1636
# 6   (737.0, 776.0]          1077      0.024141       0.099098        1543
# 7   (776.0, 819.0]          1071      0.007470       0.098546        1253
# 8   (819.0, 873.0]          1089      0.010101       0.100202        1316
# 9  (873.0, 1096.0]          1074      0.001862       0.098822        1111
#
#    OOT_set逾期率  OOT_set分布占比  数据源        指标英文 指标中文 指标类型 分箱对应原始分类       PSI
# 0    0.332629     0.065805  模型分  modelScore  模型分    /     None  0.014184
# 1    0.186463     0.104718  模型分  modelScore  模型分    /     None  0.000113
# 2    0.117480     0.122438  模型分  modelScore  模型分    /     None  0.004534
# 3    0.078271     0.118963  模型分  modelScore  模型分    /     None  0.002509
# 4    0.054239     0.111459  模型分  modelScore  模型分    /     None  0.001909
# 5    0.047066     0.113682  模型分  modelScore  模型分    /     None  0.001157
# 6    0.037589     0.107220  模型分  modelScore  模型分    /     None  0.000640
# 7    0.030327     0.087068  模型分  modelScore  模型分    /     None  0.001421
# 8    0.014438     0.091446  模型分  modelScore  模型分    /     None  0.000801
# 9    0.008101     0.077201  模型分  modelScore  模型分    /     None  0.005338

# %% [markdown]
# ### XGBExp每颗树叶子psi以及badRate

# %%
oot_model_result_exp_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_exp\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.drop('y',axis=1)\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.y,'y')

# %%
train_oot_leafs_exp_psi_badRate = ss.compare_train_OOT_leaf_psi_and_badRate(train_model_result_exp_leafs,'train',\
                                                                       oot_model_result_exp_leafs,'oot')

# %%
train_oot_leafs_exp_psi_badRate.head()
# Out:
#   var_name  leafNum  allNum_train  badNum_train  dist_train  badRate_train  \
# 0   tree_0        3           599           227    0.055116       0.378965
# 1   tree_0        4          3753           482    0.345326       0.128431
# 2   tree_0        5          6220           247    0.572322       0.039711
# 3   tree_0        6           296            66    0.027236       0.222973
# 4   tree_1        3           351           141    0.032297       0.401709
#
#    allNum_oot  badNum_oot  dist_oot  badRate_oot       psi
# 0         NaN         NaN       NaN          NaN       NaN
# 1      7044.0       824.0  0.489473     0.116979  0.050284
# 2      7279.0       374.0  0.505802     0.051381  0.008219
# 3        68.0        27.0  0.004725     0.397059  0.039431
# 4       510.0        88.0  0.035439     0.172549  0.000292

# %% [markdown]
# ## XGBRandom模型分的psi

# %%
score_ranking_train_vs_oot_XGBRandom = mt.Performance().score_ranking_psi_train_vs_oot\
(ks_decile_XGBRandom_train,ks_decile_OOT_XGBRandom_yzd_yyq)

# %%
score_ranking_train_vs_oot_XGBRandom
# Out:
#                 分箱  train_set样本量  train_set逾期率  train_set分布占比  OOT_set样本量  \
# 0   (-25.0, 492.0]          1095      0.504110       0.100755         956
# 1   (492.0, 570.0]          1085      0.192627       0.099834        1631
# 2   (570.0, 622.0]          1082      0.090573       0.099558        1735
# 3   (622.0, 665.0]          1121      0.062444       0.103147        1860
# 4   (665.0, 699.0]          1060      0.035849       0.097534        1591
# 5   (699.0, 738.0]          1084      0.020295       0.099742        1836
# 6   (738.0, 776.0]          1086      0.012891       0.099926        1441
# 7   (776.0, 818.0]          1089      0.012856       0.100202        1203
# 8   (818.0, 872.0]          1086      0.002762       0.099926        1161
# 9  (872.0, 1054.0]          1080      0.001852       0.099374         977
#
#    OOT_set逾期率  OOT_set分布占比  数据源        指标英文 指标中文 指标类型 分箱对应原始分类           PSI
# 0    0.339958     0.066430  模型分  modelScore  模型分    /     None  1.429709e-02
# 1    0.187002     0.113335  模型分  modelScore  模型分    /     None  1.712290e-03
# 2    0.110663     0.120561  模型分  modelScore  模型分    /     None  4.020332e-03
# 3    0.070430     0.129247  模型分  modelScore  模型分    /     None  5.887642e-03
# 4    0.056568     0.110555  模型分  modelScore  模型分    /     None  1.631728e-03
# 5    0.044118     0.127580  模型分  modelScore  模型分    /     None  6.852199e-03
# 6    0.037474     0.100132  模型分  modelScore  模型分    /     None  4.227447e-07
# 7    0.023275     0.083594  模型分  modelScore  模型分    /     None  3.009824e-03
# 8    0.012920     0.080675  模型分  modelScore  模型分    /     None  4.119704e-03
# 9    0.004094     0.067890  模型分  modelScore  模型分    /     None  1.199597e-02

# %% [markdown]
# ###  XGBRandom每颗树叶子psi以及badRate

# %%
oot_model_result_random_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_random\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.drop('y',axis=1)\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.y,'y')

# %%
train_oot_leafs_random_psi_badRate = ss.compare_train_OOT_leaf_psi_and_badRate(train_model_result_random_leafs,'train',\
                                                                       oot_model_result_random_leafs,'oot')

# %%
train_oot_leafs_random_psi_badRate.head(10)
# Out:
#   var_name  leafNum  allNum_train  badNum_train  dist_train  badRate_train  \
# 0   tree_0        7           320           182    0.029444       0.568750
# 1   tree_0        8           279            45    0.025672       0.161290
# 2   tree_0        9          2466           216    0.226905       0.087591
# 3   tree_0       10          1287           266    0.118421       0.206682
# 4   tree_0       11          6193           238    0.569838       0.038430
# 5   tree_0       12            27             9    0.002484       0.333333
# 6   tree_0       13           166            19    0.015274       0.114458
# 7   tree_0       14           130            47    0.011962       0.361538
# 8   tree_1        7           275            81    0.025304       0.294545
# 9   tree_1        8            76            60    0.006993       0.789474
#
#    allNum_oot  badNum_oot  dist_oot  badRate_oot       psi
# 0         NaN         NaN       NaN          NaN       NaN
# 1         NaN         NaN       NaN          NaN       NaN
# 2      4547.0       382.0  0.315961     0.084011  0.029486
# 3      2497.0       442.0  0.173511     0.177012  0.021044
# 4      7245.0       369.0  0.503440     0.050932  0.008226
# 5        34.0         5.0  0.002363     0.147059  0.000006
# 6        13.0         5.0  0.000903     0.384615  0.040638
# 7        55.0        22.0  0.003822     0.400000  0.009287
# 8       499.0        87.0  0.034674     0.174349  0.002952
# 9        11.0         1.0  0.000764     0.090909  0.013788

# %% [markdown]
# ## XGBGrid模型分psi

# %%
score_ranking_train_vs_oot_XGBGrid = mt.Performance().score_ranking_psi_train_vs_oot\
(ks_decile_XGBGrid_train,ks_decile_OOT_XGBGrid_yzd_yyq)

# %%
score_ranking_train_vs_oot_XGBGrid
# Out:
#                分箱  train_set样本量  train_set逾期率  train_set分布占比  OOT_set样本量  \
# 0   (28.0, 495.0]          1096      0.512774       0.100847         901
# 1  (495.0, 572.0]          1087      0.196872       0.100018        1668
# 2  (572.0, 621.0]          1096      0.085766       0.100847        1758
# 3  (621.0, 660.0]          1078      0.054731       0.099190        1847
# 4  (660.0, 694.0]          1083      0.033241       0.099650        1735
# 5  (694.0, 728.0]          1100      0.025455       0.101215        1843
# 6  (728.0, 763.0]          1086      0.015654       0.099926        1484
# 7  (763.0, 801.0]          1081      0.006475       0.099466        1210
# 8  (801.0, 844.0]          1076      0.004647       0.099006         994
# 9  (844.0, 949.0]          1085      0.000000       0.099834         951
#
#    OOT_set逾期率  OOT_set分布占比  数据源        指标英文 指标中文 指标类型 分箱对应原始分类       PSI
# 0    0.346282     0.062609  模型分  modelScore  模型分    /     None  0.018228
# 1    0.187650     0.115906  模型分  modelScore  模型分    /     None  0.002342
# 2    0.121160     0.122160  模型分  modelScore  模型分    /     None  0.004086
# 3    0.070384     0.128344  模型分  modelScore  模型分    /     None  0.007512
# 4    0.057061     0.120561  模型分  modelScore  模型分    /     None  0.003983
# 5    0.036896     0.128066  模型分  modelScore  模型分    /     None  0.006318
# 6    0.033693     0.103120  模型分  modelScore  模型分    /     None  0.000100
# 7    0.022314     0.084080  模型分  modelScore  模型分    /     None  0.002586
# 8    0.009054     0.069071  模型分  modelScore  模型分    /     None  0.010778
# 9    0.004206     0.066083  模型分  modelScore  模型分    /     None  0.013926

# %% [markdown]
# ### XGBGrid每颗树叶子psi以及badRate

# %%
oot_model_result_grid_leafs = ss.get_xgboost_tree_leaf_dist_and_badRate(model_result_grid\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.drop('y',axis=1)\
                                                                       ,data_OOT_final_xgboost_yzd_yyq_with_y.y,'y')

# %%
train_oot_leafs_grid_psi_badRate = ss.compare_train_OOT_leaf_psi_and_badRate(train_model_result_grid_leafs,'train',\
                                                                       oot_model_result_grid_leafs,'oot')

# %%
train_oot_leafs_grid_psi_badRate.head(18)
# Out:
#    var_name  leafNum  allNum_train  badNum_train  dist_train  badRate_train  \
# 0    tree_0       15           181            76    0.016654       0.419890
# 1    tree_0       16           139           106    0.012790       0.762590
# 2    tree_0       17           242            31    0.022267       0.128099
# 3    tree_0       18            37            14    0.003404       0.378378
# 4    tree_0       19          2294           173    0.211078       0.075414
# 5    tree_0       20           172            43    0.015826       0.250000
# 6    tree_0       21          1090           193    0.100294       0.177064
# 7    tree_0       22           197            73    0.018127       0.370558
# 8    tree_0       23          4163            87    0.383051       0.020898
# 9    tree_0       24          2030           151    0.186787       0.074384
# 10   tree_0       25            13             2    0.001196       0.153846
# 11   tree_0       26            14             7    0.001288       0.500000
# 12   tree_0       27            29            10    0.002668       0.344828
# 13   tree_0       28           137             9    0.012606       0.065693
# 14   tree_0       29            14            11    0.001288       0.785714
# 15   tree_0       30           116            36    0.010674       0.310345
# 16   tree_1       12            15             6    0.001380       0.400000
# 17   tree_1       15            26            19    0.002392       0.730769
#
#     allNum_oot  badNum_oot  dist_oot  badRate_oot       psi
# 0          NaN         NaN       NaN          NaN       NaN
# 1          NaN         NaN       NaN          NaN       NaN
# 2          NaN         NaN       NaN          NaN       NaN
# 3          NaN         NaN       NaN          NaN       NaN
# 4       4263.0       309.0  0.296227     0.072484  0.028856
# 5        284.0        73.0  0.019735     0.257042  0.000863
# 6       2169.0       332.0  0.150719     0.153066  0.020538
# 7        328.0       110.0  0.022792     0.335366  0.001069
# 8       4026.0       129.0  0.279758     0.032042  0.032459
# 9       3219.0       240.0  0.223681     0.074557  0.006650
# 10        13.0         2.0  0.000903     0.153846  0.000082
# 11        21.0         3.0  0.001459     0.142857  0.000021
# 12         7.0         3.0  0.000486     0.428571  0.003714
# 13         6.0         2.0  0.000417     0.333333  0.041552
# 14         7.0         3.0  0.000486     0.428571  0.000781
# 15        48.0        19.0  0.003335     0.395833  0.008535
# 16        11.0         2.0  0.000764     0.181818  0.000364
# 17        36.0        16.0  0.002502     0.444444  0.000005

# %% [markdown]
# # 模型部署

# %%
import utils3.deploy as dp

# %% [markdown]
# ## 生成XGBExp模型部署文档

# %%
# 引入模型的分箱明细
model_spec = load_data_from_pickle(Data_path,'%s_XGBoost输出数据和分箱明细.pkl' % 'demo_xgb')

# %%
xgb_importance_Exp = pd.read_excel(Result_path+'/demo_xgbXGBExp模型变量重要性排序.xlsx')

# %%
var_dict = pd.read_excel('/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/B_v3_var_dict_PINTEC.xlsx')

# %%
# shift+table查看每个参数含义
dp.generate_xgb_deployment_documents('demoEXP', 'EXPhasoverdue', summary,model_spec,xgb_importance_Exp,
                                      var_dict,ks_decile_XGBExp_train,model_result_exp,Result_path
                                      , production_name_map={'riskGrade':'rg'})

# %%
pd.Series(model_result_exp['model_final'].get_fscore())\
.to_frame('importance').sort_values(by='importance',ascending=False)
# Out:
#                                                 importance
# dueDaysSum30D                                           40
# fstDueLE3ToNowDays                                      32
# meanTenorHist                                           28
# rechargeNum_his                                         28
# recent_90D_tongdunIdMultiLoanNumPf                      26
# maxCuroverdueday                                        25
# lstDrawdown2AppDays                                     22
# frist3MoB                                               21
# lstDrawdown2NowDays                                     21
# apollo_osBalanceSelfProduct                             21
# recent_180D_tongdunNormalNumPfL3M                       19
# minDQduration_L3M                                       19
# meanDrawdownAmtHist                                     19
# lastLogin2Now                                           18
# fstDrawdown2NowDays                                     17
# rechargeNum_L30D                                        16
# maxDrawdownDPD120D                                      13
# TotalDPD_L3M                                            12
# minDrawdownAmt90D                                       12
# rg_binnum                                               11
# recent_30D_tongdunotherNumPfL6M                         10
# tenor12AmtCLRate180D                                     9
# recent_90D_tongdunIdMultiLoanNumPf_bin_dummy2            8
# OverdueAllNum_his                                        7
# recent_180D_tongdunotherNumPfL6M                         7
# TotalDPD_L3M_bin_dummy1                                  6
# Others_max_apply_interval_his                            6
# recent_180D_tongdunBlackDecision_binnum                  6
# dueGT3StmtRate30D_bin_dummy2                             5
# recent_30D_tongdunotherNumPfL6M_bin_dummy1               5
# dueGT3StmtRate30D_bin_dummy0                             4
# dueDaysSum30D_bin_dummy0                                 4
# recent_180D_tongdunmicrofinNumPfL6M                      3
# recent_180D_tongdunmicrofinNumPfL6M_bin_dummy1           3
# rechargeNum_his_bin_dummy1                               3
# repayFailNum_his_bin_dummy4                              3
# minDrawdownHourHist                                      3
# rechargeNum_his_bin_dummy4                               2
# maxFidDays                                               1
# dueDaysSum30D_bin_dummy1                                 1
# repayFailNum_his                                         1
# dueGT3StmtRate30D                                        1

# %% [markdown]
# ## 生成XGBGrid模型部署文档

# %%
# 引入模型的分箱明细
model_spec = load_data_from_pickle(Data_path,'%s_XGBoost输出数据和分箱明细.pkl' % 'demo_xgb')

# %%
var_dict = pd.read_excel('/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/B_v3_var_dict_PINTEC.xlsx')

# %%
xgb_importance_Grid = pd.read_excel(Result_path+'/demo_xgbXGBGrid模型变量重要性排序.xlsx')

# %%
# shift+table查看每个参数含义
dp.generate_xgb_deployment_documents('demoGrid', 'Gridhasoverdue', summary,model_spec,xgb_importance_Grid,
                                      var_dict,ks_decile_XGBGrid_train,model_result_grid,Result_path
                                      , production_name_map={})

# %%
pd.Series(model_result_grid['model_final'].get_fscore())\
.to_frame('importance').sort_values(by='importance',ascending=False)
# Out:
#                                                 importance
# meanTenorHist                                          122
# maxCuroverdueday                                       103
# recent_90D_tongdunIdMultiLoanNumPf                     103
# fstDueLE3ToNowDays                                      93
# dueDaysSum30D                                           93
# recent_180D_tongdunNormalNumPfL3M                       92
# minDQduration_L3M                                       86
# lstDrawdown2NowDays                                     79
# lstDrawdown2AppDays                                     79
# meanDrawdownAmtHist                                     78
# rechargeNum_his                                         71
# apollo_osBalanceSelfProduct                             67
# lastLogin2Now                                           65
# rechargeNum_L30D                                        56
# fstDrawdown2NowDays                                     54
# frist3MoB                                               48
# TotalDPD_L3M                                            46
# OverdueAllNum_his                                       43
# maxDrawdownDPD120D                                      42
# tenor12AmtCLRate180D                                    41
# minDrawdownAmt90D                                       34
# riskGrade_binnum                                        30
# recent_30D_tongdunotherNumPfL6M                         28
# repayFailNum_his                                        25
# recent_30D_tongdunotherNumPfL6M_bin_dummy1              23
# dueGT3StmtRate30D                                       23
# recent_180D_tongdunmicrofinNumPfL6M                     23
# recent_90D_tongdunIdMultiLoanNumPf_bin_dummy2           22
# dueDaysSum30D_bin_dummy0                                19
# maxFidDays                                              16
# recent_180D_tongdunotherNumPfL6M                        16
# minDrawdownHourHist                                     15
# recent_180D_tongdunBlackDecision_binnum                 13
# dueGT3StmtRate30D_bin_dummy2                            13
# TotalDPD_L3M_bin_dummy1                                 12
# recent_180D_tongdunmicrofinNumPfL6M_bin_dummy1          12
# dueGT3StmtRate30D_bin_dummy0                             9
# rechargeNum_his_bin_dummy4                               6
# repayFailNum_his_bin_dummy4                              6
# frist3MoB_bin_dummy0                                     6
# lastLogin2Now_bin_dummy2                                 5
# rechargeNum_his_bin_dummy1                               5
# minDrawdownAmtHist_bin_dummy0                            4
# riskGradeDUMMYRG1                                        3
# riskGradeDUMMYRG4                                        1
# lastLogin2Now_bin_dummy3                                 1
# recent_180D_tongdunotherNumPfL6M_bin_dummy3              1
# dueDaysSum30D_bin_dummy1                                 1
# minDrawdownAmtHist_bin_dummy1                            1
# Others_max_apply_interval_his                            1

# %% [markdown]
# ## 生成XGBRandom模型部署文档

# %%
# 引入模型的分箱明细
model_spec = load_data_from_pickle(Data_path,'%s_XGBoost输出数据和分箱明细.pkl' % 'demo_xgb')

# %%
var_dict = pd.read_excel('/Users/pintec/Nextcloud/Data_Science/分析文件/modeling/new_demo_data/B_v3_var_dict_PINTEC.xlsx')

# %%
xgb_importance_Random = pd.read_excel(Result_path+'/demo_xgbXGBRandom模型变量重要性排序.xlsx')

# %%
# shift+table查看每个参数含义
dp.generate_xgb_deployment_documents('demoRandom', 'Randomhasoverdue', summary,model_spec,xgb_importance_Random,
                                      var_dict,ks_decile_XGBRandom_train,model_result_random,Result_path
                                      , production_name_map={'riskGrade':'RG'})

# %%
pd.Series(model_result_random['model_final'].get_fscore())\
.to_frame('importance').sort_values(by='importance',ascending=False)
# Out:
#                                                 importance
# dueDaysSum30D                                           91
# maxCuroverdueday                                        90
# meanTenorHist                                           88
# fstDueLE3ToNowDays                                      83
# lstDrawdown2AppDays                                     78
# rechargeNum_his                                         77
# recent_90D_tongdunIdMultiLoanNumPf                      73
# lstDrawdown2NowDays                                     70
# meanDrawdownAmtHist                                     69
# fstDrawdown2NowDays                                     68
# minDQduration_L3M                                       67
# apollo_osBalanceSelfProduct                             66
# recent_180D_tongdunNormalNumPfL3M                       62
# lastLogin2Now                                           57
# frist3MoB                                               55
# rechargeNum_L30D                                        44
# maxDrawdownDPD120D                                      40
# TotalDPD_L3M                                            35
# minDrawdownAmt90D                                       34
# tenor12AmtCLRate180D                                    33
# OverdueAllNum_his                                       30
# recent_30D_tongdunotherNumPfL6M                         29
# RG_binnum                                               28
# minDrawdownHourHist                                     22
# recent_90D_tongdunIdMultiLoanNumPf_bin_dummy2           20
# dueDaysSum30D_bin_dummy0                                18
# recent_180D_tongdunmicrofinNumPfL6M                     18
# recent_30D_tongdunotherNumPfL6M_bin_dummy1              17
# recent_180D_tongdunotherNumPfL6M                        15
# dueGT3StmtRate30D                                       13
# recent_180D_tongdunBlackDecision_binnum                 13
# Others_max_apply_interval_his                           11
# repayFailNum_his                                        11
# dueGT3StmtRate30D_bin_dummy0                            10
# rechargeNum_his_bin_dummy1                               9
# recent_180D_tongdunmicrofinNumPfL6M_bin_dummy1           9
# dueGT3StmtRate30D_bin_dummy2                             9
# TotalDPD_L3M_bin_dummy1                                  8
# maxFidDays                                               7
# rechargeNum_his_bin_dummy4                               7
# repayFailNum_his_bin_dummy4                              6
# lastLogin2Now_bin_dummy2                                 6
# minDrawdownAmtHist_bin_dummy0                            5
# frist3MoB_bin_dummy0                                     3
# minDrawdownAmtHist_bin_dummy1                            3
# dueDaysSum30D_bin_dummy1                                 3
# recent_180D_tongdunotherNumPfL6M_bin_dummy3              2
# RGDUMMYRG4                                               2

# %% [markdown]
# # 模型文档整理

# %%
FINAL_REPORT_PATH = '/Users/pintec/Desktop'

# %%
import utils3.filing as fl

# %%
# python3.6的dict是ordered，按照顺序这样定义，之后生成excel的时候会按照顺序穿件sheet
data_dic = {}
# 如果sheet对应的内容是dict，则dict的key会出现在sheet第一列。value会从第二列开始插入
data_dic['01_模型结果'] = {
    '样本统计': sample_split_summary,
    #如果是图片的话必须key值中包含'_picture'，然后value为figure_path下面的图存储路径和文件名 
    'XGBExp_TRAIN_KS_picture': 'KS/demo_xgbXGBExp_TRAIN_KS.png',
    'XGBExp_TEST_KS_picture': 'KS/demo_xgbXGBExp_TEST_KS.png',
    'XGBExp_CV5_KS_picture': 'KS/demo_xgbXGBExp_5FoldCV_KS.png',
    'XGBGrid_TRAIN_KS_picture': 'KS/demo_xgbXGBGrid_TRAIN_KS.png',
    'XGBGrid_TEST_KS_picture': 'KS/demo_xgbXGBGrid_TEST_KS.png',
    'XGBGrid_CV5_KS_picture': 'KS/demo_xgbXGBGrid_5FoldCV_KS.png',
    'XGBRandom_TRAIN_KS_picture': 'KS/demo_xgbXGBRandom_TRAIN_KS.png',
    'XGBRandom_TEST_KS_picture': 'KS/demo_xgbXGBRandom_TEST_KS.png',
    'XGBRandom_CV5_KS_picture': 'KS/demo_xgbXGBRandom_5FoldCV_KS.png',  
}
data_dic['02_EDA'] = summary
data_dic['03_模型细分箱'] = woe_iv_df
data_dic['04_模型粗分箱'] = woe_iv_df_coarse
data_dic['05_决策参考'] = {'XGBExp_train_decile':ks_decile_XGBExp_train,
                          'XGBExp_test_decile':ks_decile_XGBExp_test,
                      'XGBExp_runbook':run_XGBExp_book,
                      'XGBGrid_train_decile':ks_decile_XGBGrid_train,
                        'XGBGrid_test_decile':ks_decile_XGBGrid_test,
                      'XGBGrid_runbook':run_XGBGrid_book,
                      'XGBRandom_train_decile':ks_decile_XGBRandom_train,
                        'XGBRandom_test_decile':ks_decile_XGBRandom_test,
                      'XGBRandom_runbook':run_XGBRandom_book
                      }

data_dic['06_OOT统计'] = {'XGBExp_oot_runbook':ks_decile_OOT_XGBExp_yzd_yyq,
                       'XGBExp_oot_PSI':score_ranking_train_vs_oot_XGBExp,
                       'XGBGrid_oot_runbook':ks_decile_OOT_XGBGrid_yzd_yyq,
                       'XGBGrid_oot_PSI':score_ranking_train_vs_oot_XGBGrid,
                        'XGBRandom_oot_runbook':ks_decile_OOT_XGBRandom_yzd_yyq,
                       'XGBRandom_oot_PSI':score_ranking_train_vs_oot_XGBRandom,
                       }
data_dic['07_leafs_OOT统计'] = {'train_oot_leafs_exp_psi_badRate':train_oot_leafs_exp_psi_badRate,
                       'train_oot_leafs_random_psi_badRate':train_oot_leafs_random_psi_badRate,
                       'train_oot_leafs_grid_psi_badRate':train_oot_leafs_grid_psi_badRate,
                       }
# 如果sheet对应的内容是df，则从sheet的A1位置开始插入整张表格，不包含pd.DataFrame的index
data_dic['细节1_变量按时间分布以及逾期率'] = var_dist_badRate_by_time

# %%
fl.ModelSummary2Excel(FINAL_REPORT_PATH, os.path.join(Result_path, 'figure'), 
                   'DEMO模型文档.xlsx', data_dic).run()
